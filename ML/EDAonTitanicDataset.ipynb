# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sb

# %%
plt.style.use('fivethirtyeight')

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train_data=pd.read_csv('train.csv')
test_data=pd.read_csv('test.csv')

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
test_data.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sb.countplot('Survived', data=train_data)

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
sb.countplot('Sex', hue='Survived', data=train_data)

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sb.countplot('Pclass', hue='Survived', data=train_data)
plt.show()

# %%
pd.crosstab([train_data.Sex, train_data.Survived], train_data.Pclass, margins=True)
# Out:
# Pclass             1    2    3  All
# Sex    Survived
# female 0           3    6   72   81
#        1          91   70   72  233
# male   0          77   91  300  468
#        1          45   17   47  109
# All              216  184  491  891

# %%
pd.crosstab([train_data.Sex, train_data.Survived], train_data.Pclass, margins=True).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow0_col0,#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow0_col1,#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow0_col3,#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow3_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow0_col2,#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow1_col2{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow1_col0{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow1_col1{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow1_col3{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_9483f164_2795_11ec_b7cf_c8d3ffece7efrow2_col0{
#             background-color:  #aec9fc;
# ...

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sb.factorplot('Pclass','Survived', hue='Sex', data=train_data)

# %%
x=train_data.groupby(['Sex','Pclass','Survived'])['Pclass'].count()
# y=train_data.groupby(['Sex'])['Survived']
# plt.plot(x,y,label='green')
print(x.head(10))
# print(x.columns)
plt.plot(x['Pclass'].loc[x['Sex']=='male'],x['Survived'].loc[x['Sex']=='male'], label='male')
plt.plot(x['Pclass'].loc[x['Sex']=='female'],x['Survived'].loc[x['Sex']=='female'], label='female')
# Out:
# Sex     Pclass  Survived
# female  1       0            3
#                 1           91
#         2       0            6
#                 1           70
#         3       0           72
#                 1           72
# male    1       0           77
#                 1           45
#         2       0           91
#                 1           17
# Name: Pclass, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# S:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
sb.violinplot('Pclass', 'Age', hue='Survived', data=train_data)

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sb.violinplot('Pclass', 'Age', hue='Survived', data=train_data, ax=ax[0])
sb.violinplot('Sex', 'Age', hue='Survived', data=train_data, ax=ax[1])
plt.show()

# %%
train_data.columns
train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print('Oldest person Survived was of:', train_data['Age'].loc[train_data['Survived']==1].max())
print('Youngest person Survived was of:', train_data['Age'].loc[train_data['Survived']==1].min())
print('Average person Survived was of:', train_data['Age'].loc[train_data['Survived']==1].mean())
# Out:
# Oldest person Survived was of: 80.0
# Youngest person Survived was of: 0.42
# Average person Survived was of: 28.343689655172415

# %%
print('Oldest person Survived was of:', train_data['Age'].max())
print('Youngest person Survived was of:', train_data['Age'].min())
print('Average person Survived was of:', train_data['Age'].mean())
# Out:
# Oldest person Survived was of: 80.0
# Youngest person Survived was of: 0.42
# Average person Survived was of: 29.69911764705882

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(train_data.Name.unique())
# Out:
# ['Braund, Mr. Owen Harris'
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
#  'Heikkinen, Miss. Laina' 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'
#  'Allen, Mr. William Henry' 'Moran, Mr. James' 'McCarthy, Mr. Timothy J'
#  'Palsson, Master. Gosta Leonard'
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'
#  'Nasser, Mrs. Nicholas (Adele Achem)' 'Sandstrom, Miss. Marguerite Rut'
#  'Bonnell, Miss. Elizabeth' 'Saundercock, Mr. William Henry'
#  'Andersson, Mr. Anders Johan' 'Vestrom, Miss. Hulda Amanda Adolfina'
#  'Hewlett, Mrs. (Mary D Kingcome) ' 'Rice, Master. Eugene'
#  'Williams, Mr. Charles Eugene'
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)'
#  'Masselmani, Mrs. Fatima' 'Fynney, Mr. Joseph J' 'Beesley, Mr. Lawrence'
#  'McGowan, Miss. Anna "Annie"' 'Sloper, Mr. William Thompson'
#  'Palsson, Miss. Torborg Danira'
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)'
#  'Emir, Mr. Farred Chehab' 'Fortune, Mr. Charles Alexander'
# ...

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Name=='Mr. Owen Harris'), 'Age']
# Out:
# Series([], Name: Age, dtype: float64)

# %%
train_data.loc[(train_data['Age'].isnull()) & (train_data['Initial']=='Mr'), 'Age']=33

# %%
df['val_ai'].fillna(method='ffill')

# %%
df.val_ai.quantile([0.995]).iloc[0]

# %%
import datetime
df.sort_values(by='fh')

# %%
df.drop_duplicates(subset=["c1", "c2"], keep='first')

# %%
df['c1']=df['c1'].astype(float)

# %%
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.neural_network import MLPRegressor

X=df[:,0:-1]
Y=df[:,-1:]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.3, shuffle=False)

model=Sequential()
model.add(Dense(75, input_dim=X.shape[1], kernel_initializer='normal', activation='relu'))
model.add(Dense(50, kernel_initializer='normal', activation='linear'))

# %%
model.compile(loss='mae', optimizer='adam')

# %%
history=model.fit(X, Y, epochs=150, batch_size=128, verbose=0)

# %%
Y_predicted=model.predict(X_test)
